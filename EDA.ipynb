# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jan = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/jan 26.csv")

# %%
jan.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  D90034EFC7235A41  electric_bike  2025-12-22 17:20:27.872
# 1  B005230EE77A29D0   classic_bike  2025-12-20 17:15:31.749
# 2  FD33124F2231E215   classic_bike  2025-12-06 13:38:18.275
# 3  7363165DB4BD6D14  electric_bike  2025-12-16 20:58:28.703
# 4  F09F745E43DF9556  electric_bike  2025-12-09 14:53:43.347
#
#                   ended_at              start_station_name start_station_id  \
# 0  2025-12-22 17:27:29.937           Broadway & Berwyn Ave         CHI00414
# 1  2025-12-20 17:20:07.746      Sheridan Rd & Montrose Ave         CHI00290
# 2  2025-12-06 13:52:54.682  Southport Ave & Wrightwood Ave         CHI00339
# 3  2025-12-16 21:04:35.476      Sheridan Rd & Montrose Ave         CHI00290
# 4  2025-12-09 14:58:30.944    Larrabee St & Kingsbury St 1         CHI00245
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# ...

# %%
jan.dtypes
# Out:
# ride_id                   str
# rideable_type             str
# started_at                str
# ended_at                  str
# start_station_name        str
# start_station_id          str
# end_station_name          str
# end_station_id            str
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual             str
# dtype: object

# %%
jan['started_at'] = pd.to_datetime(jan['started_at'] , errors='coerce')
jan['ended_at'] = pd.to_datetime(jan['ended_at'] , errors='coerce')

# %%
jan.dtypes
# Out:
# ride_id                          str
# rideable_type                    str
# started_at            datetime64[us]
# ended_at              datetime64[us]
# start_station_name               str
# start_station_id                 str
# end_station_name                 str
# end_station_id                   str
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                    str
# dtype: object

# %%
jan.head()
# Out:
#             ride_id  rideable_type              started_at  \
# 0  D90034EFC7235A41  electric_bike 2025-12-22 17:20:27.872
# 1  B005230EE77A29D0   classic_bike 2025-12-20 17:15:31.749
# 2  FD33124F2231E215   classic_bike 2025-12-06 13:38:18.275
# 3  7363165DB4BD6D14  electric_bike 2025-12-16 20:58:28.703
# 4  F09F745E43DF9556  electric_bike 2025-12-09 14:53:43.347
#
#                  ended_at              start_station_name start_station_id  \
# 0 2025-12-22 17:27:29.937           Broadway & Berwyn Ave         CHI00414
# 1 2025-12-20 17:20:07.746      Sheridan Rd & Montrose Ave         CHI00290
# 2 2025-12-06 13:52:54.682  Southport Ave & Wrightwood Ave         CHI00339
# 3 2025-12-16 21:04:35.476      Sheridan Rd & Montrose Ave         CHI00290
# 4 2025-12-09 14:58:30.944    Larrabee St & Kingsbury St 1         CHI00245
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# ...

# %%
jan.describe
# Out:
# <bound method NDFrame.describe of                  ride_id  rideable_type              started_at  \
# 0       D90034EFC7235A41  electric_bike 2025-12-22 17:20:27.872
# 1       B005230EE77A29D0   classic_bike 2025-12-20 17:15:31.749
# 2       FD33124F2231E215   classic_bike 2025-12-06 13:38:18.275
# 3       7363165DB4BD6D14  electric_bike 2025-12-16 20:58:28.703
# 4       F09F745E43DF9556  electric_bike 2025-12-09 14:53:43.347
# ...                  ...            ...                     ...
# 140529  53202484E8371237  electric_bike 2025-12-19 13:43:41.793
# 140530  3582BF76707AB2ED   classic_bike 2025-12-27 12:43:48.446
# 140531  B12D92DF229EFA41  electric_bike 2025-12-20 01:12:39.053
# 140532  04D5C6C11909ECAE  electric_bike 2025-12-08 16:46:37.496
# 140533  D2CF23B6D79232B6   classic_bike 2025-12-20 13:08:27.589
#
#                       ended_at              start_station_name  \
# 0      2025-12-22 17:27:29.937           Broadway & Berwyn Ave
# ...

# %%
# distribution of rides

sns.histplot(jan["rideable_type"])
# Out:
# <Axes: xlabel='rideable_type', ylabel='Count'>

# %%
#missing values 

jan.isna().sum()
# Out:
# ride_id                   0
# rideable_type             0
# started_at                0
# ended_at                  0
# start_station_name    26926
# start_station_id      26926
# end_station_name      30045
# end_station_id        30045
# start_lat                 0
# start_lng                 0
# end_lat                 122
# end_lng                 122
# member_casual             0
# dtype: int64

# %%
jan = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/jan 26.csv")
feb = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/feb 25.csv")
mar = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/march 25.csv")
apr = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/apr 25.csv")
may = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/may 25.csv")
jun = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/jun 25.csv")
jul = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/jul 25.csv")
aug = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/aug 25.csv")
sep = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/sep 25 .csv")
octt = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/oct 25.csv")
nov = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/nov 25.csv")
dec = pd.read_csv("/Users/premsundar/Downloads/DA/cyclist/Datasets/dec 25.csv")

# %%
# concat all the pandas data frames

master = pd.concat([ jan , feb , mar , apr , may , jun , jul , aug , sep , octt , nov , dec])

# %%
master.to_csv('master.csv')

# %%
master.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  D90034EFC7235A41  electric_bike  2025-12-22 17:20:27.872
# 1  B005230EE77A29D0   classic_bike  2025-12-20 17:15:31.749
# 2  FD33124F2231E215   classic_bike  2025-12-06 13:38:18.275
# 3  7363165DB4BD6D14  electric_bike  2025-12-16 20:58:28.703
# 4  F09F745E43DF9556  electric_bike  2025-12-09 14:53:43.347
#
#                   ended_at              start_station_name start_station_id  \
# 0  2025-12-22 17:27:29.937           Broadway & Berwyn Ave         CHI00414
# 1  2025-12-20 17:20:07.746      Sheridan Rd & Montrose Ave         CHI00290
# 2  2025-12-06 13:52:54.682  Southport Ave & Wrightwood Ave         CHI00339
# 3  2025-12-16 21:04:35.476      Sheridan Rd & Montrose Ave         CHI00290
# 4  2025-12-09 14:58:30.944    Larrabee St & Kingsbury St 1         CHI00245
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# ...
